# %% [markdown]
# # Extracción 📌

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
js_url = 'https://raw.githubusercontent.com/ingridcristh/challenge2-data-science-LATAM/refs/heads/main/TelecomX_Data.json'

# %%
df = pd.read_json(js_url)
df
# Out:
#       customerID Churn                                           customer  \
# 0     0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1     0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2     0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3     0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4     0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
# ...          ...   ...                                                ...
# 7262  9987-LUTYD    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 7263  9992-RRAMN   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7264  9992-UJOEL    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7265  9993-LHIEB    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 7266  9995-HOTOH    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
#
#                                                   phone  \
# ...

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Transformación 🔧

# %%
df_data = pd.json_normalize(df.to_dict(orient='records'), sep='_')
df_data
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
from os import error
df_data['account_Charges_Total'] = pd.to_numeric(
    df_data['account_Charges_Total'],
    errors='coerce'
)

df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %%
df_data['account_Charges_Total'].fillna(float(0.0), inplace=True)
df_data['account_Charges_Total'].isna().sum()
# Out:
# /tmp/ipython-input-1782329390.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_data['account_Charges_Total'].fillna(float(0.0), inplace=True)
# np.int64(0)

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customerID                 7267 non-null   object
#  1   Churn                      7267 non-null   object
#  2   customer_gender            7267 non-null   object
#  3   customer_SeniorCitizen     7267 non-null   int64
#  4   customer_Partner           7267 non-null   object
#  5   customer_Dependents        7267 non-null   object
#  6   customer_tenure            7267 non-null   int64
#  7   phone_PhoneService         7267 non-null   object
#  8   phone_MultipleLines        7267 non-null   object
#  9   internet_InternetService   7267 non-null   object
#  10  internet_OnlineSecurity    7267 non-null   object
#  11  internet_OnlineBackup      7267 non-null   object
#  12  internet_DeviceProtection  7267 non-null   object
# ...

# %%
df_data['Cuentas_Diarias'] = (df_data['account_Charges_Monthly'] / 30).astype(float)
df_data['Cuentas_Diarias'] = df_data['Cuentas_Diarias'].round(2)
df_data
# Out:
#       customerID Churn customer_gender  customer_SeniorCitizen  \
# 0     0002-ORFBO    No          Female                       0
# 1     0003-MKNFE    No            Male                       0
# 2     0004-TLHLJ   Yes            Male                       0
# 3     0011-IGKFF   Yes            Male                       1
# 4     0013-EXCHZ   Yes          Female                       1
# ...          ...   ...             ...                     ...
# 7262  9987-LUTYD    No          Female                       0
# 7263  9992-RRAMN   Yes            Male                       0
# 7264  9992-UJOEL    No            Male                       0
# 7265  9993-LHIEB    No            Male                       0
# 7266  9995-HOTOH    No            Male                       0
#
#      customer_Partner customer_Dependents  customer_tenure phone_PhoneService  \
# 0                 Yes                 Yes                9                Yes
# ...

# %%
# 1. Limpiar nombres
df_data.columns = df_data.columns.str.strip()

# 2. Renombrar
df_data.rename(columns={
    'customer_gender':'gender',
    'customer_SeniorCitizen': 'senior_65',
    'customer_Partner': 'partner',
    'customer_Dependents': 'dependents',
    'customer_tenure': 'tenure_months',
    'phone_PhoneService': 'phone_service',
    'phone_MultipleLines': 'multiple_lines',
    'internet_InternetService':'internet_service',
    'internet_OnlineSecurity': 'online_security',
    'internet_TechSupport': 'tech_support',
    'internet_OnlineBackup': 'online_backup',
    'internet_DeviceProtection': 'device_protection',
    'internet_StreamingTV': 'streaming_tv',
    'internet_StreamingMovies': 'streaming_movies',
    'account_Contract': 'contract_type',
    'account_PaperlessBilling': 'paperless_billing',
    'account_PaymentMethod': 'payment_method',
    'account_Charges_Monthly': 'monthly_charge',
    'account_Charges_Total': 'total_charge',
    'Cuentas_Diarias':'daily_charge'
}, inplace=True)

# %%
df_data['streaming_tv'].unique()
# Out:
# array(['Yes', 'No', 'No internet service'], dtype=object)

# %%
df_data.head()
# Out:
#    customerID Churn  gender  senior_65 partner dependents  tenure_months  \
# 0  0002-ORFBO    No  Female          0     Yes        Yes              9
# 1  0003-MKNFE    No    Male          0      No         No              9
# 2  0004-TLHLJ   Yes    Male          0      No         No              4
# 3  0011-IGKFF   Yes    Male          1     Yes         No             13
# 4  0013-EXCHZ   Yes  Female          1     Yes         No              3
#
#   phone_service multiple_lines internet_service online_security online_backup  \
# 0           Yes             No              DSL              No           Yes
# 1           Yes            Yes              DSL              No            No
# 2           Yes             No      Fiber optic              No            No
# 3           Yes             No      Fiber optic              No           Yes
# 4           Yes             No      Fiber optic              No            No
#
# ...

# %%
cols_finales = [
    'Churn',
    'senior_65',
    'partner',
    'dependents',
    'tenure_months',
    'contract_type',
    'monthly_charge',
    'daily_charge',
    'total_charge',
    'internet_service',
    'online_security',
    'tech_support',
    'streaming_tv',
    'payment_method'
]

df_final = df_data[cols_finales]
df_final
# Out:
#      Churn  senior_65 partner dependents  tenure_months   contract_type  \
# 0       No          0     Yes        Yes              9        One year
# 1       No          0      No         No              9  Month-to-month
# 2      Yes          0      No         No              4  Month-to-month
# 3      Yes          1     Yes         No             13  Month-to-month
# 4      Yes          1     Yes         No              3  Month-to-month
# ...    ...        ...     ...        ...            ...             ...
# 7262    No          0      No         No             13        One year
# 7263   Yes          0     Yes         No             22  Month-to-month
# 7264    No          0      No         No              2  Month-to-month
# 7265    No          0     Yes        Yes             67        Two year
# 7266    No          0     Yes        Yes             63        Two year
#
#       monthly_charge  daily_charge  total_charge internet_service  \
# ...

# %%
# Reemplazar strings vacíos por NaN
df_final.replace('', np.nan, inplace=True)
# Out:
# /tmp/ipython-input-4229487992.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final.replace('', np.nan, inplace=True)

# %%
cols_binarias = [
    'Churn',
    'partner',
    'dependents',
    'online_security',
    'tech_support',
    'streaming_tv'
]

# %%
map_binario = {'Yes': 1, 'No': 0, 'No internet service':0}

df_final.loc[:, cols_binarias] = (
    df_final[cols_binarias]
    .replace(map_binario)
)
# Out:
# /tmp/ipython-input-1770469935.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .replace(map_binario)

# %%
df_final[cols_binarias] = (
    df_final[cols_binarias]
    .fillna(0)
    .astype(int)
)
# Out:
# /tmp/ipython-input-988458819.py:3: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   .fillna(0)
# /tmp/ipython-input-988458819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final[cols_binarias] = (

# %%
df_final['payment_method'].unique()
# Out:
# array(['Mailed check', 'Electronic check', 'Credit card (automatic)',
#        'Bank transfer (automatic)'], dtype=object)

# %%
mapa_contrato = {'One year': 0, 'Month-to-month':1,'Two year':2}
mapa_internet = {'DSL':0,'Fiber optic':1,'No':2}
mapa_payment = {'Mailed check':0,'Electronic check':1,'Credit card (automatic)':2,'Bank transfer (automatic)':3}

# %%
df_final['contract_type'] = df_final['contract_type'].map(mapa_contrato)
df_final['internet_service'] = df_final['internet_service'].map(mapa_internet)
df_final['payment_method'] = df_final['payment_method'].map(mapa_payment)

df_final
# Out:
# /tmp/ipython-input-1556504895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['contract_type'] = df_final['contract_type'].map(mapa_contrato)
# /tmp/ipython-input-1556504895.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['internet_service'] = df_final['internet_service'].map(mapa_internet)
# /tmp/ipython-input-1556504895.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %% [markdown]
# # Carga y análisis 📊

# %%
df_final.describe()
# Out:
#              Churn    senior_65      partner   dependents  tenure_months  \
# count  7267.000000  7267.000000  7267.000000  7267.000000    7267.000000
# mean      0.257190     0.162653     0.484106     0.300124      32.346498
# std       0.437115     0.369074     0.499782     0.458343      24.571773
# min       0.000000     0.000000     0.000000     0.000000       0.000000
# 25%       0.000000     0.000000     0.000000     0.000000       9.000000
# 50%       0.000000     0.000000     0.000000     0.000000      29.000000
# 75%       1.000000     0.000000     1.000000     1.000000      55.000000
# max       1.000000     1.000000     1.000000     1.000000      72.000000
#
#        contract_type  monthly_charge  daily_charge  total_charge  \
# count    7267.000000     7267.000000   7267.000000   7267.000000
# mean        1.030824       64.720098      2.157292   2277.182035
# std         0.669321       30.129572      1.004407   2268.648587
# ...

# %%
df_final.groupby('Churn').mean()
# Out:
#        senior_65   partner  dependents  tenure_months  contract_type  \
# Churn
# 0       0.130789  0.527788    0.343646      37.321045       1.063357
# 1       0.254682  0.357945    0.174425      17.979133       0.936865
#
#        monthly_charge  daily_charge  total_charge  internet_service  \
# Churn
# 0           61.354224      2.045056   2535.263977          0.896073
# 1           74.441332      2.481450   1531.796094          0.814874
#
#        online_security  tech_support  streaming_tv  payment_method
# Churn
# 0             0.330308      0.332345      0.366062        1.489255
# 1             0.157838      0.165864      0.435527        1.235420

# %%
cols_validas = [
    'senior_65', 'partner', 'dependents',
    'tenure_months','contract_type',
    'monthly_charge', 'daily_charge', 'total_charge',
    'online_security', 'tech_support', 'streaming_tv','payment_method'
]

df_grup = df_final.groupby('Churn')[cols_validas].mean()
df_grup
# Out:
#        senior_65   partner  dependents  tenure_months  contract_type  \
# Churn
# 0       0.130789  0.527788    0.343646      37.321045       1.063357
# 1       0.254682  0.357945    0.174425      17.979133       0.936865
#
#        monthly_charge  daily_charge  total_charge  online_security  \
# Churn
# 0           61.354224      2.045056   2535.263977         0.330308
# 1           74.441332      2.481450   1531.796094         0.157838
#
#        tech_support  streaming_tv  payment_method
# Churn
# 0          0.332345      0.366062        1.489255
# 1          0.165864      0.435527        1.235420

# %%
df_grup_reset = df_grup.reset_index()

grouped_melt = df_grup_reset.melt(
    id_vars='Churn',
    value_vars=['tenure_months', 'monthly_charge'],
    var_name='Variable',
    value_name='Promedio'
)

ax = sns.barplot(
    data=grouped_melt,
    x='Variable',
    y='Promedio',
    hue='Churn'
)

handles, labels = ax.get_legend_handles_labels()
ax.legend(
    handles,
    ['No canceló', 'Canceló'],
    title='Estado de cancelación'
)

plt.title('Comparación de promedios por Churn')
plt.xticks([0, 1], ['Meses Contratados', 'Cargo mensual'])
plt.show()

# %%
df_contratos = df_final.groupby(['Churn', 'contract_type']).size().reset_index(name='count')

df_contratos['total'] = df_contratos.groupby('contract_type')['count'].transform('sum')
df_contratos['churn_rate'] = df_contratos['count'] / df_contratos['total']

df_contratos
# Out:
#    Churn  contract_type  count  total  churn_rate
# 0      0              0   1353   1519    0.890718
# 1      0              1   2350   4005    0.586767
# 2      0              2   1695   1743    0.972461
# 3      1              0    166   1519    0.109282
# 4      1              1   1655   4005    0.413233
# 5      1              2     48   1743    0.027539

# %%
sns.barplot(
    data=df_contratos[df_contratos['Churn'] == 1],
    x='contract_type',
    y='churn_rate'
)

plt.title('Tasa de cancelación por tipo de contrato')
plt.ylabel('Proporción de cancelacion')
plt.xlabel('Tipo de contrato')
plt.xticks([0,1,2], ['Anual', 'Mensual', '2 Años'])
plt.show()

# %%
df_pagos = df_final.groupby(['Churn', 'payment_method']).size().reset_index(name='count')
df_pagos['total'] = df_pagos.groupby('payment_method')['count'].transform('sum')
df_pagos['churn_rate'] = df_pagos['count'] / df_pagos['total'] * 100

df_pagos
# Out:
#    Churn  payment_method  count  total  churn_rate
# 0      0               0   1357   1665   81.501502
# 1      0               1   1374   2445   56.196319
# 2      0               2   1336   1568   85.204082
# 3      0               3   1331   1589   83.763373
# 4      1               0    308   1665   18.498498
# 5      1               1   1071   2445   43.803681
# 6      1               2    232   1568   14.795918
# 7      1               3    258   1589   16.236627

# %%
sns.barplot(
    data=df_pagos[df_pagos['Churn'] == 1],
    x='payment_method',
    y='churn_rate'
)

plt.title('Tasa de cancelación por método de pago')
plt.ylabel('Proporción de cancelacion')
plt.xlabel('Método de pago')
plt.xticks([0,1,2,3],['Cheques', 'Cheque Electronico', 'Tarjeta de crédito', 'Transferencia bancaria'], rotation=10)
plt.show()

# %%
sns.boxplot(data=df_final, x='Churn', y='monthly_charge')
plt.title('Distribución de cargos mensuales')
plt.xticks([0,1], ['No canceló', 'Canceló'])
plt.title('Distribución de cancelacion por cargos mensuales')
plt.show()

# %%
sns.histplot(data=df_final,
             x='monthly_charge',
             hue='Churn',
             kde=True)
plt.title('Distribución de cancelacion por cargos mensuales')
plt.xlabel('Cargo mensual')
plt.ylabel('Cancelaciones')
plt.show()

# %%
cols_corr = [
    'Churn',
    'tenure_months',
    'monthly_charge',
    'total_charge',
    'daily_charge'
]

df_corr = df_final[cols_corr].corr(method='pearson')

hm_corr = sns.heatmap(df_corr, annot=True, cmap='coolwarm')
plt.title('Correlación entre variables numéricas y Churn')
plt.savefig('heatmap.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# # Informe final 📄

# %% [markdown]
# ## Introduccion
#
# En el siguiente proyecto se trata el tema de la evasion o cancelacion de pago de los clientes de la empresa Telecom X, la cual es una empresa de telecomunicaciones que ofrecen principalmente servicios de internet y telefonia, la razon de este proyecto es identificar el problema principal de la cancelacion de los clientes (Churn), el cual esta actualmente en el 25%, que parece poco pero es algo a tomar en cuenta.
#
# "Churn" vendria siendo la forma de llamar a la cancelacion o evasion de los clientes, lo principal de este proyecto sera identificar cual es el factor principal para que el porcentaje de "Churn" se encuentre en el nivel actual.
#
# Es importante analizar esta problematica ya que podremos idenficar problematicas que los clientes estan observando y que nosotros como empresa no nos estamos dando cuenta, y esto es lo que puede llevar a que los clientes actualmente esten cancelando sus servicios, pero para eso tendremos que analizar e identificar la problematica principal.
#
# Hipotesis:
# La hipotesis principal que formulee antes de analizar los datos que se me fueron entregados fueron 3, ya que esas son las problematicas que mas se caracterizan en este tipo de servicios y por ende lleva a los clientes a la cancelacion y cambio de servicios hacia otras empresas, la primera problematica planteada fue acerca de la calidad de servicio de internet, ya que actualmente la empresa cuenta con dos servicios de internet las cuales son DSL y fibra optica, los cuales la conexion por cable DSL es la que suele presentar una mayor cantidad de fallas en el servicio, asi que las personas con este tipo de internet son las que mas podrian presentar su disgusto en la calidad del servicio y por ende en la cancelacion del servicio. La siguiente problematica planteada fue acerca de los adultos mayores de 65 años o mas, esto debido aque este tipo de personas no suele usar mucho el internet, por lo que al ellos o sus familiares determinar que el servicio es innecesario terminan optando por cancelar el servicio. Y la ultima problematica planteada fue acerca del precio, que los clientes al momento de estar pagando el servicio se les hacia caro o que simplemente los gastos que tenian no podian sustentar los precios de los servicios establecidos por la empresa.

# %% [markdown]
# ## Limpieza y Tratamiento de datos
#
# La limpieza de estos datos consisitio en el uso de la libreria "pandas" principalmente, pandas es una libreria de python utilizada especificificamente para la carga y la transformacion de los datos, los datos venian en un archivo JSON, asi que tuvimos que utilizar "pandas" y su metodo "read_json()" para poder cargar estos datos, pero al momento de cargar el dataframe nos dimos cuenta que los datos venian en multiples diccionarios dentro del JSON, por lo que tuvimos que usar otro metodo de la libreria "pandas" la cual fue "json_normalize()" y dentro de los parametros tuvimos que transformarlo con un metodo de "pandas" la cual fue "to_list(), esto para poder leer correctamente el archivo JSON, al momento de cargar este DataFrame utilizamos la funcion "info()", para explorar a mayor profundidad este DataFrame, lo cual nos ayudo a identificar columnas que necesitaban ser transformadas para cambiar su formato a numerico, por lo que con el metodo "to_numeric" que viene incluido en esta libreria, logramos convertir una columna que estaba su formato original en String la pasamos a una variable numerica, y al momento de pasarla le especificamos con el metodo "errors='coerce'" que cualquier registro que diera un error fuera pasado como valor NaN, para despues hacer la conversion de estos valores NaN y cambiarlos por valores numericos esto con la funcion "fillna()" esto para no tener ningun valor nulo en el dataframe, se creo una columna nueva para determinar el gasto diario y para eso utilizamos la columna de "cargos_mensuales" y la dividimos entra 30 y con la funcion "astype(float)" trasnformamos esta columna a tipo numerico flotante.
#
# Para transformar las columnas del DataFrame se utilizo el metodo "rename(columns=)" esto para pasarle un diccionario con el "nombreDeColumna:NuevoNombre", esto para hacer que las columnas tenga una mejor presentacion y no tenga nombres tan enredosos, antes de esto tuvimos que utilizar la funcion "strip()" para eliminar cualquier espacio o caracter en las columnas que no se ve a simple vista y no tener problemas al momento de hacer la transformacion del formato de las columnas, se decidio hacer una transformacion en los registros del DataFrame, esto para poder preparar el proyecto en caso de ser necesario un proyecto de Machine Learning (ML), se decidio cambiar los registros tanto de las variables numericas como de las categoricas, a valores de 0 y 1 en las numericas y de 0 a 3 en las categoricas, la descripcion de cada una de las columnas se encuentran especificadas en el "readME.md".

# %% [markdown]
# ## Analisis Exploratorio de Datos (EDA)
#
# <img src="graficas/barplot1.png" width="900">
#
# La primera grafica realizada nos muestra una problematica planteada, lo cual nos muestra que las personas que duran pocos meses con el servicio contratado son las que en promedio realizan la cancelacion, esto se puede traducir a que duran poco con el servicio ya que no se les brindo el servicio correcto o algo no les gusto, y si pasamos a la siguiente comparativa podemos empezar a aclarar un poco mas esto, ya que tambien se nos muestra que las personas que cancelan el servicio vienen siendo las personas que pagan mas, por lo que puede que se muestre una incomodidad con el servicio o con el precio de este.
#
# <img src="graficas/barplot2.png" width="900">
#
# En esta segunda grafica podemos observar una tendencia bastante curiosa, y es que el porcentaje de cancelacion aumenta significativamente con los clientes que su contrato de pago es de mes con mes, la razon principal de cancelamiento puede ser que son clientes que estan probando el servicio y determinando si se quedan o no, o puede ser tambien que la cancelacion se deba a que son clientes que que sus gastos totales mensuales no les permitan seguir con el servicio.
#
# <img src="graficas/boxplot.png" width="900">
#
# En esta grafica de caja, lo que podemos observar principalmente es la distribucion en la cancelacion del servicio, ya que podemos observar que la mayoria de clientes que cancelan se encuentran en el rango de entre los $60 y $95, mientras que las personas que no cancelan es una mayor parte pero la parte interesante aqui viene siendo que el rango es mucho mayor ya que va desde los $22 hasta los $85, por lo que puede ser que las personas esten cancelando por que el servicio se les hace demasiado caro.
#
# <img src="graficas/histograma.png" width="900">
#
# En el histograma presentado podemos ver de mejor manera la grafica de caja que vimos anteriormente, en este histograma podemos ver las diferentes varianzas que han habido en las cancelaciones tomando en cuenta el cargo mensual de las personas, a lo que aqui vemos que los niveles de cancelacion son minimos partiendo desde los $20 hasta los $60, pero la cosa cambia cuando entramos en el rango de los $80 hasta los $100, las tasas de cancelacion aumentan significativamente en comparacion a los clientes que se quedan.
#
# <img src="graficas/heatmap.png" width="900">
#
# A continuacion se muestra un mapa de calor, en el cual nos deja ver de mejor forma la relacion que se tiene con las diferentes variables, a lo que podemos ver que la relacion mas fuerte que existe en este mapa viene siendo la de los meses contratados por los clientes y el cargo mensual que pagan los clientes, por lo que podemos comprobar que las personas que cancelan tienen pocos meses con el servicio contratado ya que se les hace caro lo que pagan.

# %% [markdown]
# ## Conclusiones
#
# Como ya lo pudimos ver, hay una fuerte relacion entre la cancelacion del servicio y el precio del servicio, esto es lo que lleva a que las personas se desanimen o busquen otras opciones, ya que tal vez sienten que el precio es demasiado caro o simplemente busquen opciones mas accesibles para su economia, por lo que despues de realizar este analisis podemos llegar a la conclusion de que las personas cancelan su servicio con Telecom X debido a los precios de este, ya que como pudimos ver la mayor parte de las personas que cancelan estan en los rangos de los precios mas caros, por lo que es logico pensar que cancelan para poder buscar opciones mas economicas que puedan cubrir sus necesidades basicas de este tipo de servicios, es por eso que las personas que menos han cancelado el servicio son personas que tienen contratos de 1 o 2 años ya pagados, ya que son personas que tienen una solvencia economica un poco mejor a la de los otros tipos de personas.

# %% [markdown]
# ## Recomendaciones
#
# Mis recomendaciones para la empresa Telecom X vendrian siendo las siguientes:
#
# 1.- Ofrecer paquetes con servicios de telecomunicaciones y servicios de software para las personas que hagan contrato de 1 o 2 años, para que esten con incentivos de seguir con el contrato.
#
# 2.- Dar mantenimiento constante, para que los clientes tengan un servicio de calidad.
#
# 3.- Introducir mas paquetes economicos, principalmente paquetes que busquen cubrir necesidades basicas a un precio asequible.
#
# 4.- Ofrecer los paquetes mas economicos a las personas que cancelaron, esto para poder mantener el mercado que se tenia antes de la cancelacion y tambien para atraer a mas clientes que esten buscando opciones mas economicas.
